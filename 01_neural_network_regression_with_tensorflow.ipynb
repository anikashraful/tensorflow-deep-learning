# %%
import tensorflow as tf
print(tf.__version__) # check the version (should be 2.x+)

import datetime
print(f"Notebook last run (end-to-end): {datetime.datetime.now()}")
# Out:
# 2.20.0
# Notebook last run (end-to-end): 2025-11-21 21:05:58.914277

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize it
plt.scatter(X, y);

# %%
# Example input and output shapes of a regression model
house_info = tf.constant(["bedroom", "bathroom", "garage"])
house_price = tf.constant([939700])
house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
house_info.shape
# Out:
# TensorShape([3])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create features (using tensors)
X = tf.constant([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels (using tensors)
y = tf.constant([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize it
plt.scatter(X, y);

# %%
# Take a single example of X
input_shape = X[0].shape 

# Take a single example of y
output_shape = y[0].shape

input_shape, output_shape # these are both scalars (no shape)
# Out:
# (TensorShape([]), TensorShape([]))

# %%
# Let's take a look at the single examples invidually
X[0], y[0]
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=-7.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=3.0>)

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model using the Sequential API
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              optimizer=tf.keras.optimizers.SGD(), # SGD is short for stochastic gradient descent
              metrics=["mae"])

# Fit the model
# model.fit(X, y, epochs=5) # this will break with TensorFlow 2.7.0+
model.fit(tf.expand_dims(X, axis=-1), y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 8.7282 - mae: 8.7282
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 8.5957 - mae: 8.5957
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 8.4632 - mae: 8.4632
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 8.3307 - mae: 8.3307
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 8.1982 - mae: 8.1982

# %%
# Check out X and y
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# Make a prediction with the model
model.predict([17.0])

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model (same as above)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# Fit model (this time we'll train for longer)
model.fit(tf.expand_dims(X, axis=-1), y, epochs=100) # train for 100 epochs not 10
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 13.5719 - mae: 13.5719
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 13.4394 - mae: 13.4394
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 13.3069 - mae: 13.3069
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 13.1744 - mae: 13.1744
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 13.0419 - mae: 13.0419
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 12.9094 - mae: 12.9094
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 12.7769 - mae: 12.7769
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 12.6444 - mae: 12.6444
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 12.5119 - mae: 12.5119
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 12.3794 - mae: 12.3794
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 12.2469 - mae: 12.2469
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 12.1144 - mae: 12.1144
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 11.9819 - mae: 11.9819
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 11.8494 - mae: 11.8494
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 11.7169 - mae: 11.7169
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 11.5844 - mae: 11.5844
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 11.4519 - mae: 11.4519
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 11.3194 - mae: 11.3194
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 11.1869 - mae: 11.1869
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 11.0544 - mae: 11.0544
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 10.9219 - mae: 10.9219
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 10.7894 - mae: 10.7894
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 10.6569 - mae: 10.6569
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 10.5244 - mae: 10.5244
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 10.3919 - mae: 10.3919
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 10.2594 - mae: 10.2594
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 10.1269 - mae: 10.1269
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 9.9944 - mae: 9.9944
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 9.8619 - mae: 9.8619
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 9.7294 - mae: 9.7294
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 9.5969 - mae: 9.5969
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 9.4644 - mae: 9.4644
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 9.3319 - mae: 9.3319
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 9.1994 - mae: 9.1994
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 9.0669 - mae: 9.0669
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 8.9344 - mae: 8.9344
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 8.8019 - mae: 8.8019
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 8.6694 - mae: 8.6694
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 8.5369 - mae: 8.5369
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 8.4044 - mae: 8.4044
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 8.2719 - mae: 8.2719
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - loss: 8.1394 - mae: 8.1394
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 8.0069 - mae: 8.0069
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 7.8744 - mae: 7.8744
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 7.7419 - mae: 7.7419
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 7.6094 - mae: 7.6094
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 7.4770 - mae: 7.4770
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 7.3444 - mae: 7.3444
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 7.2120 - mae: 7.2120
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 7.1325 - mae: 7.1325
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 7.1269 - mae: 7.1269
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 7.1213 - mae: 7.1213
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 7.1156 - mae: 7.1156
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 7.1100 - mae: 7.1100
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 7.1044 - mae: 7.1044
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 7.0988 - mae: 7.0988
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 7.0931 - mae: 7.0931
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 7.0875 - mae: 7.0875
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 7.0819 - mae: 7.0819
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 7.0763 - mae: 7.0763
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 7.0706 - mae: 7.0706
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 7.0650 - mae: 7.0650
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 7.0594 - mae: 7.0594
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - loss: 7.0538 - mae: 7.0538
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 7.0481 - mae: 7.0481
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 7.0425 - mae: 7.0425
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 7.0369 - mae: 7.0369
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 7.0312 - mae: 7.0312
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 7.0256 - mae: 7.0256
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 7.0200 - mae: 7.0200
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 7.0144 - mae: 7.0144
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 7.0088 - mae: 7.0088
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 7.0031 - mae: 7.0031
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 6.9975 - mae: 6.9975
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 6.9919 - mae: 6.9919
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 6.9863 - mae: 6.9863
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 6.9806 - mae: 6.9806
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 6.9750 - mae: 6.9750
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 6.9694 - mae: 6.9694
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 6.9638 - mae: 6.9638
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 6.9581 - mae: 6.9581
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 6.9525 - mae: 6.9525
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 6.9469 - mae: 6.9469
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 6.9413 - mae: 6.9413
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 6.9356 - mae: 6.9356
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 6.9300 - mae: 6.9300
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 6.9244 - mae: 6.9244
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 6.9188 - mae: 6.9188
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 6.9131 - mae: 6.9131
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 6.9075 - mae: 6.9075
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 6.9019 - mae: 6.9019
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 6.8963 - mae: 6.8963
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 6.8906 - mae: 6.8906
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 6.8850 - mae: 6.8850
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 6.8794 - mae: 6.8794
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 6.8738 - mae: 6.8738
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 6.8681 - mae: 6.8681
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 6.8625 - mae: 6.8625
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 6.8569 - mae: 6.8569
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 6.8513 - mae: 6.8513

# %%
# Remind ourselves of what X and y are
X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
# Try and predict what y would be if X was 17.0
model.predict([17.0]) # the right answer is 27.0 (y = X + 10)

# %%
# Make a bigger dataset
X = np.arange(-100, 100, 4)
X
# Out:
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96])

# %%
y = np.arange(-90, 110, 4)
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# Same result as above
y = X + 10
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# Check how many samples we have
len(X)
# Out:
# 50

# %%
# Split data into train and test sets
X_train = X[:40] # first 40 examples (80% of data)
y_train = y[:40]

X_test = X[40:] # last 10 examples (20% of data)
y_test = y[40:]

len(X_train), len(X_test)
# Out:
# (40, 10)

# %%
plt.figure(figsize=(10, 7))
# Plot training data in blue
plt.scatter(X_train, y_train, c='b', label='Training data')
# Plot test data in green
plt.scatter(X_test, y_test, c='g', label='Testing data')
# Show the legend
plt.legend();

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model (same as above)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1, input_shape=[1]) # define the input_shape to our model
])

# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])
# Out:
# C:\Users\Anik\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# This will work after specifying the input shape
model.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit the model to the training data
model.fit(X_train, y_train, epochs=100, verbose=0)

# %%
# Check the model summary
model.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4 (20.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# !pip install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydot in c:\users\anik\appdata\roaming\python\python312\site-packages (4.0.1)
# Requirement already satisfied: pyparsing>=3.1.0 in c:\users\anik\appdata\roaming\python\python312\site-packages (from pydot) (3.2.5)

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# Make predictions
y_preds = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step

# %%
# View the predictions
y_preds
# Out:
# array([[ 68.67388 ],
#        [ 73.158264],
#        [ 77.64265 ],
#        [ 82.12703 ],
#        [ 86.61141 ],
#        [ 91.095795],
#        [ 95.580185],
#        [100.06457 ],
#        [104.54895 ],
#        [109.03333 ]], dtype=float32)

# %%
def plot_predictions(train_data=X_train, 
                     train_labels=y_train, 
                     test_data=X_test, 
                     test_labels=y_test, 
                     predictions=y_preds):
  """
  Plots training data, test data and compares predictions.
  """
  plt.figure(figsize=(10, 7))
  # Plot training data in blue
  plt.scatter(train_data, train_labels, c="b", label="Training data")
  # Plot test data in green
  plt.scatter(test_data, test_labels, c="g", label="Testing data")
  # Plot the predictions in red (predictions were made on the test data)
  plt.scatter(test_data, predictions, c="r", label="Predictions")
  # Show the legend
  plt.legend();

# %%
plot_predictions(train_data=X_train,
                 train_labels=y_train,
                 test_data=X_test,
                 test_labels=y_test,
                 predictions=y_preds)

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - loss: 1.3586 - mae: 1.3586
# [1.3586479425430298, 1.3586479425430298]

# %%
# Calculate the mean absolute error
mae = tf.metrics.mean_absolute_error(y_true=y_test, 
                                     y_pred=y_preds)
mae

# %%
# Check the test label tensor values
y_test
# Out:
# array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# Check the predictions tensor values (notice the extra square brackets)
y_preds
# Out:
# array([[ 68.67388 ],
#        [ 73.158264],
#        [ 77.64265 ],
#        [ 82.12703 ],
#        [ 86.61141 ],
#        [ 91.095795],
#        [ 95.580185],
#        [100.06457 ],
#        [104.54895 ],
#        [109.03333 ]], dtype=float32)

# %%
# Check the tensor shapes
y_test.shape, y_preds.shape
# Out:
# ((10,), (10, 1))

# %%
# Shape before squeeze()
y_preds.shape
# Out:
# (10, 1)

# %%
# Shape after squeeze()
y_preds.squeeze().shape
# Out:
# (10,)

# %%
# What do they look like?
y_test, y_preds.squeeze()
# Out:
# (array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106]),
#  array([ 68.67388 ,  73.158264,  77.64265 ,  82.12703 ,  86.61141 ,
#          91.095795,  95.580185, 100.06457 , 104.54895 , 109.03333 ],
#        dtype=float32))

# %%
# Calcuate the MAE
mae = tf.metrics.mean_absolute_error(y_true=y_test, 
                                     y_pred=y_preds.squeeze()) # use squeeze() to make same shape
mae

# %%
# Calculate the MSE
mse = tf.metrics.mean_squared_error(y_true=y_test,
                                    y_pred=y_preds.squeeze())
mse

# %%
# Returns the same as tf.metrics.mean_absolute_error()
tf.reduce_mean(tf.abs(y_test-y_preds.squeeze()))

# %%
def mae(y_test, y_pred):
      """
  Calculuates mean absolute error between y_test and y_preds.
  """
  return tf.metrics.mean_absolute_error(y_test,
                                        y_pred)
  
def mse(y_test, y_pred):
  """
  Calculates mean squared error between y_test and y_preds.
  """
  return tf.metrics.mean_squared_error(y_test,
                                       y_pred)

# %%
# Set random seed
tf.random.set_seed(42)

# Replicate original model
model_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(1)
])

# Compile the model
model_1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# Fit the model
model_1.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 24.5029 - mae: 24.5029
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 10.8148 - mae: 10.8148
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 7.6021 - mae: 7.6021
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 8.9238 - mae: 8.9238
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 10.0332 - mae: 10.0332
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 11.5252 - mae: 11.5252
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 8.9997 - mae: 8.9997
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 10.1091 - mae: 10.1091
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 11.6729 - mae: 11.6729
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 12.5607 - mae: 12.5607
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 8.3518 - mae: 8.3518
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 9.0317 - mae: 9.0317
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.8513 - mae: 7.8513
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 10.8199 - mae: 10.8199
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 7.5991 - mae: 7.5991
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 11.8742 - mae: 11.8742
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 8.2738 - mae: 8.2738
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 8.9477 - mae: 8.9477
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 7.7823 - mae: 7.7823
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 10.7322 - mae: 10.7322
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.5353 - mae: 7.5353
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 11.7862 - mae: 11.7862
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 8.1958 - mae: 8.1958
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 8.7100 - mae: 8.7100
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 8.5986 - mae: 8.5986
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 8.3315 - mae: 8.3315
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 9.0909 - mae: 9.0909
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 8.1793 - mae: 8.1793
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 8.8690 - mae: 8.8690
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 7.6721 - mae: 7.6721
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 10.6770 - mae: 10.6770
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.4172 - mae: 7.4172
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 11.7390 - mae: 11.7390
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 8.1013 - mae: 8.1013
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 8.7850 - mae: 8.7850
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 7.6031 - mae: 7.6031
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 10.5893 - mae: 10.5893
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 7.3534 - mae: 7.3534
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 11.6510 - mae: 11.6510
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 8.0233 - mae: 8.0233
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.7010 - mae: 8.7010
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 7.5341 - mae: 7.5341
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 10.5015 - mae: 10.5015
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.2897 - mae: 7.2897
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 11.5630 - mae: 11.5630
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 7.7583 - mae: 7.7583
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 9.4912 - mae: 9.4912
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.9280 - mae: 7.9280
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 8.6026 - mae: 8.6026
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 7.4450 - mae: 7.4450
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 10.4037 - mae: 10.4037
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 7.2044 - mae: 7.2044
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 11.4664 - mae: 11.4664
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 7.6658 - mae: 7.6658
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 9.3925 - mae: 9.3925
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.6471 - mae: 7.6471
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 9.3796 - mae: 9.3796
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 7.6284 - mae: 7.6284
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.3666 - mae: 9.3666
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 7.7983 - mae: 7.7983
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 8.4755 - mae: 8.4755
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 7.3156 - mae: 7.3156
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 10.2858 - mae: 10.2858
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.0759 - mae: 7.0759
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 11.3525 - mae: 11.3525
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7.5360 - mae: 7.5360
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 9.2679 - mae: 9.2679
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 7.5173 - mae: 7.5173
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 9.2550 - mae: 9.2550
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.6858 - mae: 7.6858
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 8.3627 - mae: 8.3627
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 7.2063 - mae: 7.2063
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 10.1779 - mae: 10.1779
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 6.9691 - mae: 6.9691
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 11.2472 - mae: 11.2472
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.4249 - mae: 7.4249
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.1563 - mae: 9.1563
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 7.4062 - mae: 7.4062
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 9.2657 - mae: 9.2657
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 6.8444 - mae: 6.8444
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 9.3947 - mae: 9.3947
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 10.9648 - mae: 10.9648
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 11.9021 - mae: 11.9021
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.5669 - mae: 7.5669
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 8.2637 - mae: 8.2637
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.0676 - mae: 7.0676
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 10.1086 - mae: 10.1086
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 6.8205 - mae: 6.8205
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 11.2825 - mae: 11.2825
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6.7998 - mae: 6.7998
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 11.2092 - mae: 11.2092
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 6.6422 - mae: 6.6422
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.9902 - mae: 7.9902
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 9.0995 - mae: 9.0995
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 10.5377 - mae: 10.5377
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 8.0660 - mae: 8.0660
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 9.1754 - mae: 9.1754
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 10.6847 - mae: 10.6847
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 11.9124 - mae: 11.9124
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 7.4589 - mae: 7.4589

# %%
# Make and plot predictions for model_1
y_preds_1 = model_1.predict(X_test)
plot_predictions(predictions=y_preds_1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step

# %%
# Calculate model_1 metrics
mae_1 = mae(y_test, y_preds_1.squeeze()).numpy()
mse_1 = mse(y_test, y_preds_1.squeeze()).numpy()
mae_1, mse_1

# %%
# Set random seed
tf.random.set_seed(42)

# Replicate model_1 and add an extra layer
model_2 = tf.keras.Sequential([
  tf.keras.layers.Dense(1),
  tf.keras.layers.Dense(1) # add a second layer
])

# Compile the model
model_2.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# Fit the model
model_2.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
# Make and plot predictions for model_2
y_preds_2 = model_2.predict(X_test)
plot_predictions(predictions=y_preds_2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step

# %%
model_results = [["model_1", mae_1, mse_1],
                 ["model_2", mae_2, mse_2],
                 ["model_3", mae_3, mae_3]]
